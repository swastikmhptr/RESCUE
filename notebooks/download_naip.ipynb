# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys 

sys.path.append('../src')

import geopandas as gpd 
from rescue import naip
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = naip.download_naip_for_geojson(
geojson_path = '../data/sample_geojsons/sample_1.geojson',
time_range = "2018-01-01/2027-01-01", 
)

## to save to disk
## img.to_netcdf("FILE PATH YOU WANT.nc")

## to load to a file
## xr.open_datset("FILE PATH YOU WANT.nc")

# %%
rgb = np.moveaxis(img.values[:3], 0, -1)

rgb.shape
# Out:
# (1131, 1967, 3)

# %%
plt.imshow(rgb)
